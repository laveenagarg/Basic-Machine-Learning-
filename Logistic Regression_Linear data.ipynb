# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn import metrics

# %%
#importing data
data = pd.read_csv("C://Users/LAVEENA/Desktop/LRdata1.txt")

#slicing data to X and y
X = data.iloc[:,0:2]
y = data.iloc[:,2]

#further slicing into a and b, 2 different features
a = X.iloc[:,0]
b = X.iloc[:,1]

# %%
#plotting features on both axis and corresponding labels
fig = plt.figure(figsize=(8,8))
plt.scatter(a, b, c=y)

# %%
#splitting data into train and test data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

#fitting logistic regression into X_train,y_train
model = LogisticRegression().fit(X_train,y_train)
y_pred = model.predict(X_test)
# Out:
# C:\Users\LAVEENA\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %%
cnf_matrix = metrics.confusion_matrix(y_test, y_pred)
cnf_matrix #prints confusion metrix

print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
print("Precision:",metrics.precision_score(y_test, y_pred))
print("Recall:",metrics.recall_score(y_test, y_pred))
# Out:
# Accuracy: 0.65
# Precision: 0.5882352941176471
# Recall: 1.0

# %%
y_pre = model.predict(X)
plt.scatter(a, b, c=y_pre) #plotting predicted labels

# %% [markdown]
# #We can see comparing both the graphs our output prediction and actual labels, this can further be improves using regularization.
